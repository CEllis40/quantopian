# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5e92a19f74b8894598fb84d3')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:14|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2011-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2012-07-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.202%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-0.317%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.268%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
# ...
